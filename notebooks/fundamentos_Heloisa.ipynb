# %% [markdown]
# <a href="https://colab.research.google.com/github/gheloisar/fundamentos/blob/main/notebooks/fundamentos_Heloisa.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Importação dos programas utilizados

# %%
import json
import numpy as np
import pandas as pd
import plotly.express as px

# %% [markdown]
# #Acesso ao Google Drive

# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# #Acesso a base de dados

# %%
caminho_padrao = '/content/gdrive/MyDrive'
caminho_especifico = '/pibic_jr_2024'
caminho_completo = caminho_padrao + caminho_especifico

# %%
df_discursos = pd.read_json(f'{caminho_completo}/bd/BD_BRASIL_GOVFEDERAL_BIBLIOTECA_PRESIDENCIA-bolsonaro-discursos.json', orient='columns')
df_discursos = pd.json_normalize(df_discursos['_default'])
df_discursos
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-51-f92f37668eb4> in <cell line: 1>()
# ----> 1 df_discursos = pd.read_json(f'{caminho_completo}/bd/BD_BRASIL_GOVFEDERAL_BIBLIOTECA_PRESIDENCIA-bolsonaro-discursos.json', orient='columns')
#       2 df_discursos = pd.json_normalize(df_discursos['_default'])
#       3 df_discursos
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/json/_json.py in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, precise_float, date_unit, encoding, encoding_errors, lines, chunksize, compression, nrows, storage_options, dtype_backend, engine)
#     789         convert_axes = True
#     790
# --> 791     json_reader = JsonReader(
#     792         path_or_buf,
#     793         orient=orient,
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/json/_json.py in __init__(self, filepath_or_buffer, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, precise_float, date_unit, encoding, lines, chunksize, compression, nrows, storage_options, encoding_errors, dtype_backend, engine)
#     902             self.data = filepath_or_buffer
#     903         elif self.engine == "ujson":
# --> 904             data = self._get_data_from_filepath(filepath_or_buffer)
#     905             self.data = self._preprocess_data(data)
#     906
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/json/_json.py in _get_data_from_filepath(self, filepath_or_buffer)
#     958             and not file_exists(filepath_or_buffer)
#     959         ):
# --> 960             raise FileNotFoundError(f"File {filepath_or_buffer} does not exist")
#     961         else:
#     962             warnings.warn(
#
# FileNotFoundError: File /content/gdrive/MyDrive/pibic_jr_2024/bd/BD_BRASIL_GOVFEDERAL_BIBLIOTECA_PRESIDENCIA-bolsonaro-discursos.json does not exist

# %% [markdown]
# #Pré análise

# %%
df_discursos.shape
# Out:
# (611, 32)

# %%
df_discursos.columns
# Out:
# Index(['tipo_dado', 'pais', 'origem', 'sigla', 'classificado', 'categoria',
#        'autoria', 'titulo', 'subtitulo', 'data', 'horario', 'data_atualizado',
#        'horario_atualizado', 'link', 'link_archive', 'data_archive',
#        'horario_archive', 'local', 'tags', 'edicao', 'editor', 'paragrafos',
#        'nome_arquivo', 'imagens', 'dir_bd', 'dir_arquivo', 'codigo_bd',
#        'nome_bd_json', 'env_dir_bd', 'extra_01', 'extra_02', 'extra_03'],
#       dtype='object')

# %%
df_discursos = df_discursos[['data','titulo','link']]
df_discursos
# Out:
#            data                                             titulo  \
# 0    21/02/2022  Discurso do Presidente da República, Jair Bols...
# 1    22/02/2022  Discurso do Presidente da República, Jair Bols...
# 2    23/02/2022  Discurso do Presidente da República, Jair Bols...
# 3    23/02/2022  Discurso do Presidente da República, Jair Bols...
# 4    24/02/2022  Discurso do Presidente da República, Jair Bols...
# ..          ...                                                ...
# 606  02/12/2019  Discurso do Presidente da República, Jair Bols...
# 607  03/12/2019  Discurso do Presidente da República, Jair Bols...
# 608  05/12/2019  Discurso do Presidente da República, Jair Bols...
# 609          NA  Discurso do Senhor Presidente da República, Ja...
# 610  07/12/2019  Discurso do Presidente da República, Jair Bols...
#
#                                                   link
# 0    http://www.biblioteca.presidencia.gov.br/presi...
# 1    http://www.biblioteca.presidencia.gov.br/presi...
# 2    http://www.biblioteca.presidencia.gov.br/presi...
# 3    http://www.biblioteca.presidencia.gov.br/presi...
# 4    http://www.biblioteca.presidencia.gov.br/presi...
# ..                                                 ...
# 606  http://www.biblioteca.presidencia.gov.br/presi...
# 607  http://www.biblioteca.presidencia.gov.br/presi...
# 608  http://www.biblioteca.presidencia.gov.br/presi...
# 609  http://www.biblioteca.presidencia.gov.br/presi...
# 610  http://www.biblioteca.presidencia.gov.br/presi...
#
# [611 rows x 3 columns]

# %%
discursos_sem_data = df_discursos[df_discursos["data"]=="NA"]
discursos_sem_data
# Out:
#     data                                             titulo  \
# 39    NA  Discurso do Presidente da República, Jair Bols...
# 83    NA  Discurso do Presidente da República, Jair Bols...
# 92    NA  Discurso do Presidente da República, Jair Bols...
# 95    NA  Discurso do Presidente da República, Jair Bols...
# 96    NA  Discurso do Presidente da República, Jair Bols...
# ..   ...                                                ...
# 573   NA  Discurso do Presidente da República, Jair Bols...
# 591   NA  Discurso do Presidente da República, Jair Bols...
# 592   NA  Discurso do Presidente da República, Jair Bols...
# 604   NA  Discurso do Presidente da República, Jair Bols...
# 609   NA  Discurso do Senhor Presidente da República, Ja...
#
#                                                   link
# 39   http://www.biblioteca.presidencia.gov.br/presi...
# 83   http://www.biblioteca.presidencia.gov.br/presi...
# 92   http://www.biblioteca.presidencia.gov.br/presi...
# 95   http://www.biblioteca.presidencia.gov.br/presi...
# 96   http://www.biblioteca.presidencia.gov.br/presi...
# ..                                                 ...
# 573  http://www.biblioteca.presidencia.gov.br/presi...
# 591  http://www.biblioteca.presidencia.gov.br/presi...
# 592  http://www.biblioteca.presidencia.gov.br/presi...
# 604  http://www.biblioteca.presidencia.gov.br/presi...
# 609  http://www.biblioteca.presidencia.gov.br/presi...
#
# [170 rows x 3 columns]

# %%
df_discursos['data'] = pd.to_datetime(df_discursos['data'], format = '%d/%m/%Y', errors = "coerce")
df_discursos['ano'] = pd.to_datetime(df_discursos['data']).dt.year
discursos_por_ano = df_discursos['ano'].value_counts().sort_index()
discursos_por_ano = discursos_por_ano.to_frame()
discursos_por_ano
# Out:
# <ipython-input-13-68919eead4f0>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_discursos['data'] = pd.to_datetime(df_discursos['data'], format = '%d/%m/%Y', errors = "coerce")
# <ipython-input-13-68919eead4f0>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_discursos['ano'] = pd.to_datetime(df_discursos['data']).dt.year
#         count
# ano
# 2018.0      3
# 2019.0    168
# 2020.0     86
# 2021.0     79
# 2022.0    105
